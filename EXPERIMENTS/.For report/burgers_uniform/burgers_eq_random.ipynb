# %% [markdown]
# # 1D Burgers Equation DEMO code

# %% [markdown]
# This notebook demonstrates solving 1D Burgers Equation (spatial xy version) using PINNs.

# %%
import deepflow as df
print("Deepflow is runned on:", df.device) # to change to cpu use df.device = 'cpu'
df.manual_seed(69) # for reproducibility
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import deepflow as df
#       2 print("Deepflow is runned on:", df.device) # to change to cpu use df.device = 'cpu'
#       3 df.manual_seed(69) # for reproducibility
#
# File ~\OneDrive\Documents\1 - Projects\0 - STEM\2 - Numerical Physics\9 - PINNs\deepflow\src\deepflow\__init__.py:6
#       4 from .pde import *
#       5 from .nn import *
# ----> 6 from .qnn import *
#       7 from .evaluation import *
#       8 from .utility import device, get_device, manual_seed
#
# File ~\OneDrive\Documents\1 - Projects\0 - STEM\2 - Numerical Physics\9 - PINNs\deepflow\src\deepflow\qnn.py:6
#       2 from .nn import NN
#       4 from torch import nn
# ----> 6 import pennylane as qml
#       7 class QPINN(NN):
#       8     def __init__(
#       9         self,
#      10         input_vars: Optional[List[str]] = None,
#    (...)     16         activation: nn.Module = nn.Tanh()
#      17     ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pennylane\__init__.py:105
#     103 from pennylane.templates.subroutines import *
#     104 from pennylane import qaoa
# --> 105 from pennylane.workflow import QNode, qnode, execute, set_shots, marker
#     106 from pennylane import workflow
#     108 from pennylane.transforms import (
#     109     transform,
#     110     batch_params,
#    (...)    123     CompilePipeline,
#     124 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pennylane\workflow\__init__.py:47
#       1 # Copyright 2018-2024 Xanadu Quantum Technologies Inc.
#       2
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """
#      15 This module contains the core objects for managing a PennyLane workflow.
#      16
#    (...)     45
#      46 """
# ---> 47 from .construct_batch import construct_batch, get_transform_program, marker
#      48 from .construct_tape import construct_tape
#      49 from .construct_execution_config import construct_execution_config
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pennylane\workflow\construct_batch.py:22
#      19 from typing import TYPE_CHECKING, Literal
#      21 import pennylane as qml
# ---> 22 from pennylane.transforms.core import CompilePipeline, transform
#      24 from ._setup_transform_program import _setup_transform_program
#      25 from .qnode import _make_execution_config
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pennylane\transforms\__init__.py:424
#     422 from .dynamic_one_shot import dynamic_one_shot, is_mcm
#     423 from .sign_expand import sign_expand
# --> 424 from .split_non_commuting import split_non_commuting
#     425 from .split_to_single_terms import split_to_single_terms
#     426 from .combine_global_phases import combine_global_phases
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pennylane\transforms\split_non_commuting.py:28
#      25 from typing import Literal
#      27 import numpy as np
# ---> 28 from scipy.stats import multinomial
#      30 import pennylane as qml
#      31 from pennylane.measurements import ExpectationMP, MeasurementProcess, StateMP
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_stats_py.py:42
#      39 from scipy import sparse
#      40 from scipy.spatial import distance_matrix
# ---> 42 from scipy.optimize import milp, LinearConstraint
#      43 from scipy._lib._util import (check_random_state, _get_nan,
#      44                               _rename_parameter, _contains_nan,
#      45                               normalize_axis_index, np_vecdot, AxisError)
#      46 from scipy._lib.deprecation import _deprecate_positional_args, _deprecated
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\__init__.py:435
#     433 from ._nnls import nnls
#     434 from ._basinhopping import basinhopping
# --> 435 from ._linprog import linprog, linprog_verbose_callback
#     436 from ._lsap import linear_sum_assignment
#     437 from ._differentialevolution import differential_evolution
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_linprog.py:21
#      19 from ._optimize import OptimizeResult, OptimizeWarning
#      20 from warnings import warn
# ---> 21 from ._linprog_highs import _linprog_highs
#      22 from ._linprog_ip import _linprog_ip
#      23 from ._linprog_simplex import _linprog_simplex
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_linprog_highs.py:20
#      18 from ._optimize import OptimizeWarning, OptimizeResult
#      19 from warnings import warn
# ---> 20 from ._highspy._highs_wrapper import _highs_wrapper
#      21 from ._highspy._core import(
#      22     kHighsInf,
#      23     HighsDebugLevel,
#    (...)     26     simplex_constants as s_c,  # [1]
#      27 )
#      28 from scipy.sparse import csc_array, vstack, issparse
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 1. Define Geometry Domain
# Set up the computational domain

# %%
area = df.geometry.rectangle([-1, 1], [0, 1])
line_ic = df.geometry.line_horizontal(y=0, range_x=[-1,1])
line_bc1 = df.geometry.line_vertical(x=-1, range_y=[0,1])
line_bc2 = df.geometry.line_vertical(x=1, range_y=[0,1])
domain = df.domain(area.area_list, line_ic, line_bc1, line_bc2)
domain.show_setup()
# Out:
# Figure(nrows=1, ncols=1, refwidth=np.float64(7.0))

# %% [markdown]
# ## 2. Define Physics
# Define the Burgers eq (spatial version) apply boundary conditions.

# %%
# Define PDE
from torch import sin, pi
domain.area_list[0].define_pde(df.pde.BurgersEquation1D(nu=0.01/pi))
domain.bound_list[0].define_bc({'u':['x', lambda x: -sin(pi * x)]})
domain.bound_list[1].define_bc({'u': 0})
domain.bound_list[2].define_bc({'u': 0})

# %% [markdown]
# ### 2. Generate Training Data

# %% [markdown]
# Sample initial points for training. After sampling, Deepflow will automatically generate training datasets based on the defined physics.

# %%
# Sample points: [Left, Bottom, Right, Top], [Interior]
domain.sampling_lhs([200, 50, 50], [200])
domain.show_coordinates(display_physics=True)
# Out:
# Figure(nrows=1, ncols=1, refwidth=np.float64(7.0))

# %% [markdown]
# ### 3. Train the Model

# %% [markdown]
# Define the resampling scheme during training. [R3](https://arxiv.org/abs/2207.02338) scheme is recommended.

# %%
def do_in_adam(epoch, model):
    return
    if epoch % 150 == 0 and epoch > 0:
        domain.sampling_lhs([100, 50, 50], [400])
        #domain.sampling_R3([200, 100, 100], [400])
        print(domain)
        
def do_in_lbfgs(epoch, model):
    return
    if epoch % 150 == 0 and epoch > 0:
        domain.sampling_lhs([100, 50, 50], [400])
        #domain.sampling_R3([200, 100, 100], [400])
        print(domain)

# %% [markdown]
# Train the model using Adam optimizer followed by L-BFGS optimizer.

# %%
model0 = df.QCPINN(input_vars=['x','y'], output_vars=['u'], hidden_layer_pre=[50], hidden_layer_post=[50], nqubits=5)

model1, model1_best = model0.train_adam(
    calc_loss = df.calc_loss_simple(domain),
    learning_rate=0.004,
    epochs=500,
    do_between_epochs=do_in_adam)
# Out:
# Epoch: 1, total_loss: 0.86148, bc_loss: 0.86117, pde_loss: 0.00031
# Training interrupted by user.

# %%
model2 = model1.train_lbfgs(
    calc_loss = df.calc_loss_simple(domain), 
    epochs=500, 
    do_between_epochs=do_in_lbfgs,
)
# Out:
# Epoch: 501, total_loss: 0.09465, bc_loss: 0.05808, pde_loss: 0.03657
# Epoch: 551, total_loss: 0.07438, bc_loss: 0.04704, pde_loss: 0.02734
# Epoch: 601, total_loss: 0.05816, bc_loss: 0.03825, pde_loss: 0.01991
# Training interrupted by user.

# %%
domain.show_coordinates(display_physics=False)
# Out:
# Figure(nrows=1, ncols=1, refwidth=np.float64(7.0))

# %% [markdown]
# ## 4. Visualization

# %%
# Evaluate the best model
prediction = domain.area_list[0].evaluate(model2)
# Sampling uniform points
prediction.sampling_area([500, 250])

# %% [markdown]
# ### 4.1 Visualize PDE area

# %%
# Plot Velocity Field
prediction.plot_color('u', cmap = 'jet', s=0.3).savefig('u_field.png')
_ = prediction.plot_color('pde_residual', cmap = 'rainbow', s=0.3)
_ = prediction.plot('pde_residual')
_ = prediction.plot_loss_curve(log_scale=True)
# Out:
# C:\Users\thamm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\events.py:82: UltraPlotWarning: Tick label sharing not implemented for <class 'ultraplot.axes.three.ThreeAxes'> subplots.
#   func(*args, **kwargs)
# Figure(nrows=1, ncols=1, refwidth=np.float64(6.0))
# Figure(nrows=1, ncols=1, refwidth=np.float64(6.0))
# C:\Users\thamm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UltraPlotWarning: Tick label sharing not implemented for <class 'ultraplot.axes.three.ThreeAxes'> subplots.
#   fig.canvas.print_figure(bytes_io, **kw)
# Figure(nrows=1, ncols=1, refwidth=np.float64(6.0))
# Figure(nrows=1, ncols=1, refwidth=np.float64(5.0), refheight=np.float64(3.0))

# %% [markdown]
# ### 4.2 Visualize u at y = 0.75

# %%
line = df.geometry.line_horizontal(y=0.75, range_x=[-1, 1])
prediction = line.evaluate(model2)
prediction.sampling_line(500)
_ = prediction.plot(y_axis = 'u')
# Out:
# Figure(nrows=1, ncols=1, refwidth=np.float64(6.0))
