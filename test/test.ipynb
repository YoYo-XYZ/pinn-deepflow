# %%
import matplotlib.pyplot as plt
import numpy as np

w = 3
Y, X = np.mgrid[-w:w:4j, -w:w:4j]

# %%
print(X)
# Out:
# [[-3. -1.  1.  3.]
#  [-3. -1.  1.  3.]
#  [-3. -1.  1.  3.]
#  [-3. -1.  1.  3.]]

# %%
print(Y)
# Out:
# [[-3. -3. -3. -3.]
#  [-1. -1. -1. -1.]
#  [ 1.  1.  1.  1.]
#  [ 3.  3.  3.  3.]]
